# %%
import pandas as pd
import numpy as np

# %%
train_start = pd.read_csv('train_x_predic623.csv', index_col=0)
test_start = pd.read_csv('test_x_predic623.csv', index_col = 0)

# %%
train_start.columns
# Out:
# Index([u'gender', u'age', u'signup_method', u'signup_flow', u'language',
#        u'affiliate_channel', u'affiliate_provider', u'first_affiliate_tracked',
#        u'signup_app', u'first_device_type', u'first_browser',
#        u'population_in_thousands', u'sum_secs_elapsed', u'counts'],
#       dtype='object')

# %%
pd.get_dummies(train_start)
# Out:
# Index([u'Unnamed: 0', u'gender', u'age', u'signup_method', u'signup_flow',
#        u'language', u'affiliate_channel', u'affiliate_provider',
#        u'first_affiliate_tracked', u'signup_app', u'first_device_type',
#        u'first_browser', u'population_in_thousands', u'sum_secs_elapsed',
#        u'counts'],
#       dtype='object')

# %%
dummied = pd.get_dummies(train_start)

# %%
dummied.columns
# Out:
# Index([u'signup_flow', u'sum_secs_elapsed', u'counts', u'gender_FEMALE',
#        u'gender_MALE', u'gender_OTHER', u'age_0-4', u'age_100+', u'age_15-19',
#        u'age_20-24',
#        ...
#        u'population_in_thousands_881.0', u'population_in_thousands_895.0',
#        u'population_in_thousands_9.0', u'population_in_thousands_906.0',
#        u'population_in_thousands_914.0', u'population_in_thousands_918.0',
#        u'population_in_thousands_9217.0', u'population_in_thousands_973.0',
#        u'population_in_thousands_978.0', u'population_in_thousands_NB'],
#       dtype='object', length=474)

# %%
# Out:
#         gender    age signup_method  signup_flow language affiliate_channel  \
# 0          NaN    NaN      facebook            0       en            direct
# 1         MALE  35-39      facebook            0       en               seo
# 2       FEMALE  55-59         basic            3       en            direct
# 3       FEMALE  40-44      facebook            0       en            direct
# 4          NaN  40-44         basic            0       en            direct
# 5          NaN    NaN         basic            0       en             other
# 6       FEMALE  45-49         basic            0       en             other
# 7       FEMALE  45-49         basic            0       en            direct
# 8       FEMALE  50-54         basic            0       en             other
# 9          NaN  45-49         basic            0       en             other
# 10      FEMALE  35-39         basic            0       en             other
# ...

# %%
test_start.head()
# Out:
#    gender    age signup_method  signup_flow language affiliate_channel  \
# 0  FEMALE  35-39      facebook            0       en            direct
# 1     NaN    NaN         basic            0       en            direct
# 2     NaN    NaN         basic            0       en            direct
# 3     NaN    NaN         basic            0       en            direct
# 4     NaN    NaN         basic            0       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked      Moweb            iPhone
# 1             direct               untracked      Moweb            iPhone
# 2             direct                  linked        Web   Windows Desktop
# 3             direct                  linked        Web   Windows Desktop
# 4             direct               untracked        Web       Mac Desktop
#
#    first_browser  population_in_thousands  sum_secs_elapsed  counts
# ...
